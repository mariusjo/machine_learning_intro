# %% [markdown]
# # Predicting Diabetes
#
# ## Import Libraries

# %%
import pandas as pd             # pandas is a dataframe library
import matplotlib
import matplotlib.pyplot as plt # matplotlib.pyplot plots data
import numpy as np              #numpy provides N-dim object support

# do ploting inline instead of in a separate window
# %matplotlib inline
matplotlib.style.use('classic')

# %% [markdown]
# ## Load and review data

# %%
df = pd.read_csv("./data/pima-data.csv") # load Pima data.

# %%
df.shape
# Out:
# (768, 10)

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
df.tail(5)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin  diabetes
# 763      0.171   63  1.8912     False
# 764      0.340   27  1.0638     False
# 765      0.245   30  0.9062     False
# 766      0.349   47  0.0000      True
# 767      0.315   23  1.2214     False

# %% [markdown]
# ### Definition of features
# From the metadata on the data source we have the following definition of the features.
#
#
#
# | Feature  | Description | Comments |
# |--------------|-------------|--------|
# | num_preg     | number of pregnancies         |-|
# | glucose_conc | Plasma glucose concentration a 2 hours in an oral glucose tolerance test         |-|
# | diastolic_bp | Diastolic blood pressure (mm Hg) |-|
# | thickness | Triceps skin fold thickness (mm) |-|
# |insulin | 2-Hour serum insulin (mu U/ml) |-|
# | bmi |  Body mass index (weight in kg/(height in m)^2) |-|
# | diab_pred |  Diabetes pedigree function |-|
# | Age (years) | Age (years)|-|
# | skin | ???? | What is this? |
# | diabetes | Class variable (1=True, 0=False) |  Why is our data boolean (True/False)? |

# %%
df.isnull().values.any()
# Out:
# False

# %%
def plot_corr(df, size=11):
    """
    Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot

    Displays:
        matrix of correlation between columns.  Blue-cyan-yellow-red-darkred => less to more correlated
                                                0 ------------------>  1
                                                Expect a darkred line running from top left to bottom right
    """

    corr = df.corr()    # data frame correlation function
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)   # color code the rectangles by correlation value
    plt.xticks(range(len(corr.columns)), corr.columns)  # draw x tick marks
    plt.yticks(range(len(corr.columns)), corr.columns)  # draw y tick marks

# %%
plot_corr(df)

# %%
df.corr()
# Out:
#               num_preg  glucose_conc  diastolic_bp  thickness   insulin  \
# num_preg      1.000000      0.129459      0.141282  -0.081672 -0.073535
# glucose_conc  0.129459      1.000000      0.152590   0.057328  0.331357
# diastolic_bp  0.141282      0.152590      1.000000   0.207371  0.088933
# thickness    -0.081672      0.057328      0.207371   1.000000  0.436783
# insulin      -0.073535      0.331357      0.088933   0.436783  1.000000
# bmi           0.017683      0.221071      0.281805   0.392573  0.197859
# diab_pred    -0.033523      0.137337      0.041265   0.183928  0.185071
# age           0.544341      0.263514      0.239528  -0.113970 -0.042163
# skin         -0.081672      0.057328      0.207371   1.000000  0.436783
# diabetes      0.221898      0.466581      0.065068   0.074752  0.130548
#
#                    bmi  diab_pred       age      skin  diabetes
# num_preg      0.017683  -0.033523  0.544341 -0.081672  0.221898
# ...

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# 3   21  0.9062     False
# 4   33  1.3790      True

# %%
del df['skin']

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True

# %%
plot_corr(df)

# %% [markdown]
# ### Check Data Types

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50      True
# 1   31     False
# 2   32      True
# 3   21     False
# 4   33      True

# %% [markdown]
# The algorithm works with numeric values. Change True to 1, False to 0

# %%
diabetes_map = {True: 1, False: 0}

# %%
df['diabetes'] = df['diabetes'].map(diabetes_map)

# %%
df.head(5)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %% [markdown]
# ### Check True/False ratio
#
# Is the case we are trying to predict happening often enough so that we can learn from it? No hard limit.

# %%
num_obs = len(df)
num_true = len(df.loc[df['diabetes'] == True])
num_false = len(df.loc[df['diabetes'] == False])
print("Number of True cases:  {0} ({1:2.2f}%)".format(num_true, (num_true/num_obs) * 100))
print("Number of False cases: {0} ({1:2.2f}%)".format(num_false, (num_false/num_obs) * 100))
# Out:
# Number of True cases:  268 (34.90%)
# Number of False cases: 500 (65.10%)

# %% [markdown]
# ### Splitting the data
#
# 70 % for training, 30% for testing

# %%
from sklearn.cross_validation import train_test_split

feature_col_names = ['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin', 'bmi', 'diab_pred', 'age']
predicted_class_names = ['diabetes']

X = df[feature_col_names].values       # predictor feature columns (8 X m)
y = df[predicted_class_names].values   # predicted class (1=True, 0=False) column (1 X m)
split_test_size = 0.30

#test_size = 0.3 is 30%, 42 is the answer to everything
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_test_size, random_state=42)
# Out:
# C:\Users\mariu\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# We check to ensure we have the desired 70% train, 30% test split of the data

# %%
print("{0:0.2f}% in training set".format(((len(X_train))/(len(df.index)))*100))
print("{0:0.2f}% in test set".format(((len(X_test))/(len(df.index)))*100))
# Out:
# 69.92% in training set
# 30.08% in test set

# %% [markdown]
# #### Verifying predicted value was split correctly

# %%
print("Original True  : {0} ({1:0.2f}%)".format(len(df.loc[df['diabetes'] == 1]), (len(df.loc[df['diabetes'] == 1])/len(df.index)) * 100.0))
print("Original False : {0} ({1:0.2f}%)".format(len(df.loc[df['diabetes'] == 0]), (len(df.loc[df['diabetes'] == 0])/len(df.index)) * 100.0))
print("")
#print(y_train)
#print(y_train[:] == 1)
#print(y_train[y_train[:] == 1])
print("Training True  : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 1]), (len(y_train[y_train[:] == 1])/len(y_train) * 100.0)))
print("Training False : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 0]), (len(y_train[y_train[:] == 0])/len(y_train) * 100.0)))
print("")
print("Test True      : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 1]), (len(y_test[y_test[:] == 1])/len(y_test) * 100.0)))
print("Test False     : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 0]), (len(y_test[y_test[:] == 0])/len(y_test) * 100.0)))
# Out:
# Original True  : 268 (34.90%)
# Original False : 500 (65.10%)
#
# Training True  : 188 (35.01%)
# Training False : 349 (64.99%)
#
# Test True      : 80 (34.63%)
# Test False     : 151 (65.37%)

# %% [markdown]
# ### Post-split Data Preparation

# %% [markdown]
# #### Hidden Missing Values

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %% [markdown]
# Are these 0 values possible (f.eks. thickness)?
#
# How many rows have unexpected 0 values?

# %%
print("# rows in dataframe {0}".format(len(df)))
print("# rows missing glucose_conc: {0}".format(len(df.loc[df['glucose_conc'] == 0])))
print("# rows missing diastolic_bp: {0}".format(len(df.loc[df['diastolic_bp'] == 0])))
print("# rows missing thickness: {0}".format(len(df.loc[df['thickness'] == 0])))
print("# rows missing insulin: {0}".format(len(df.loc[df['insulin'] == 0])))
print("# rows missing bmi: {0}".format(len(df.loc[df['bmi'] == 0])))
print("# rows missing diab_pred: {0}".format(len(df.loc[df['diab_pred'] == 0])))
print("# rows missing age: {0}".format(len(df.loc[df['age'] == 0])))
# Out:
# # rows in dataframe 768
# # rows missing glucose_conc: 5
# # rows missing diastolic_bp: 35
# # rows missing thickness: 227
# # rows missing insulin: 374
# # rows missing bmi: 11
# # rows missing diab_pred: 0
# # rows missing age: 0

# %% [markdown]
# #### Impute the mean

# %%
from sklearn.preprocessing import Imputer

#Impute with mean all 0 readings

fill_0 = Imputer(missing_values=0, strategy="mean", axis=0)

X_train = fill_0.fit_transform(X_train)
X_test = fill_0.fit_transform(X_test)

# %% [markdown]
# ## Training Initial Algorithm - Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# create Gaussian Naive Bayes Model object and train it with the data
nb_model = GaussianNB()

nb_model.fit(X_train, y_train.ravel())
# Out:
# GaussianNB(priors=None)

# %% [markdown]
# ### Performance on Training Data

# %%
# predict values using the training data
nb_predict_train = nb_model.predict(X_train)

from sklearn import metrics

print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, nb_predict_train)))
# Out:
# Accuracy: 0.7542

# %% [markdown]
# ### Performance on Testing Data

# %%
# predict values using the testing data
nb_predict_test = nb_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, nb_predict_test)))
# Out:
# Accuracy: 0.7359

# %% [markdown]
# #### Metrics

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, nb_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, nb_predict_test))
# Out:
# Confusion Matrix
# [[118  33]
#  [ 28  52]]
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.81      0.78      0.79       151
#           1       0.61      0.65      0.63        80
#
# avg / total       0.74      0.74      0.74       231

# %% [markdown]
# recall: true positive rate / sensitivity
# , or: How many of the patient who actially has diabetes did we predict?
#
# Recall = \frac{TP}{TP+FN}
#
# Precision : How often the patient actualy has diabetes when the model said they would.
#
# Precision = \frac{TP}{TP+FN}

# %% [markdown]
# ## Performance improvement options
#
# * Adjust current algorithm
#     * Naive bayes has no hyperparameters, so this is not an option here.
# * Get more data or improve data
#     * We have no more data and have allready improved it quite a bit
# * Improve training
# * Switch algorithms
#     * Let's try Random Forests

# %% [markdown]
# ### Random Forest
#
# * Ensamble algorithm
# * Fits multiple trees with subsets of data
# * Averages tree results to improve performance and controll overfitting

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)    # Create random forest object
rf_model.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# ### Predict Training Data

# %%
rf_predict_train = rf_model.predict(X_train)
# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, rf_predict_train)))
# Out:
# Accuracy: 0.9870

# %% [markdown]
# ### Predict Test Data

# %%
rf_predict_test = rf_model.predict(X_test)
# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, rf_predict_test)))
# Out:
# Accuracy: 0.7100

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, rf_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, rf_predict_test))
# Out:
# Confusion Matrix
# [[121  30]
#  [ 37  43]]
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.77      0.80      0.78       151
#           1       0.59      0.54      0.56        80
#
# avg / total       0.70      0.71      0.71       231

# %% [markdown]
# when we a gap in accuracy from training data to test data this big (0.987-0.71), it is usually a sign that the algorithm has *overfitted* the trainingdata. The algorithm has learned the training data *to well*.
#
# **Two primary techniques to handle overfitting:**
#
# Both of these can be used at the same time.
#
# 1. Tuning the Regularization Parameter
# * Many algorithms has a tunig parameter / hyperparameter often called Regularization.
#     * Tells the algorithm how much to focus on precisely fitting every corner case of the training data.
#     * Example for where the \lambda is the regularisation param: y = x_{1} + w_{2}x_{2}^3 + w_{3}x_{3}^8 - \frac{f(W)}{\lambda}
#         * dampening
# * Algorithms that has regularization params reacts differently to the data and values of the hyperparams.
#     * Some experimentation is required to get the best values for each hyperparm with a specific set of data.
#
# 2. Cross validation
#
# * This is when we use multiple subsets of the training data during the training process
#
#
# **Bias - variance trade-off:**
# * Compromise between
#     * accuracy with training data
#     * accuracy with testing and real-world data

# %% [markdown]
# ## Logistic Regression
# A basic algorithm

# %%
from sklearn.linear_model import LogisticRegression

# C param in constructor is the regularization hyperparam. we start by guessing 0.7
lr_model = LogisticRegression(C=0.7, random_state=42)
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, lr_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
# Out:
# Accuracy: 0.7446
# Confusion Matrix
# [[128  23]
#  [ 36  44]]
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.78      0.85      0.81       151
#           1       0.66      0.55      0.60        80
#
# avg / total       0.74      0.74      0.74       231

# %% [markdown]
# Setting the regularization parameter

# %%
C_start = 0.1
C_end = 5
C_inc = 0.1

C_values, recall_scores = [], []

C_val = C_start
best_recall_score = 0
while (C_val < C_end):
    C_values.append(C_val)
    lr_model_loop = LogisticRegression(C=C_val, random_state=42)
    lr_model_loop.fit(X_train, y_train.ravel())
    lr_predict_loop_test = lr_model_loop.predict(X_test)
    recall_score = metrics.recall_score(y_test, lr_predict_loop_test)
    recall_scores.append(recall_score)
    if (recall_score > best_recall_score):
        best_recall_score = recall_score
        best_lr_predict_test = lr_predict_loop_test
        
    C_val = C_val + C_inc
    
best_score_C_val = C_values[recall_scores.index(best_recall_score)]
print("1st max value of {0:.3f} occured at C={1:.3f}".format(best_recall_score, best_score_C_val))

# %matplotlib inline
plt.plot(C_values, recall_scores, "-")
plt.xlabel("C value")
plt.ylabel("recall score")
# Out:
# 1st max value of 0.613 occured at C=1.400
# Text(0,0.5,'recall score')

# %% [markdown]
# Still pretty low recall score, at 0.613. What else can we do?
#
# Remember that the dataset contains way more non diabetes results then diabetse results.
# Perhaps this imbalance is causing an issue.

# %% [markdown]
# ### Unbalanced Classes
# * More of one class than the others
# * Our Data - 65% No Diabetes, 35% Diabetes
# * Can be causing biases estimation yielding poor prediction results
# * Many algorithms, including logistics regression in scikit-learn, include a hyperparam that instructs
#   algorithm to compensate for the class imbalance. The result is a shift in the predicted class boundry.

# %% [markdown]
# ### Logistic regression with class_weight="balanced"

# %%
C_start = 0.1
C_end = 5
C_inc = 0.1

C_values, recall_scores = [], []

C_val = C_start
best_recall_score = 0
while (C_val < C_end):
    C_values.append(C_val)
    lr_model_loop = LogisticRegression(C=C_val, class_weight="balanced", random_state=42)
    lr_model_loop.fit(X_train, y_train.ravel())
    lr_predict_loop_test = lr_model_loop.predict(X_test)
    recall_score = metrics.recall_score(y_test, lr_predict_loop_test)
    recall_scores.append(recall_score)
    if (recall_score > best_recall_score):
        best_recall_score = recall_score
        best_lr_predict_test = lr_predict_loop_test
        
    C_val = C_val + C_inc
    
best_score_C_val = C_values[recall_scores.index(best_recall_score)]
print("1st max value of {0:.3f} occured at C={1:.3f}".format(best_recall_score, best_score_C_val))

# %matplotlib inline
plt.plot(C_values, recall_scores, "-")
plt.xlabel("C value")
plt.ylabel("recall score")
# Out:
# 1st max value of 0.738 occured at C=0.300
# Text(0,0.5,'recall score')

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression( class_weight="balanced", C=best_score_C_val, random_state=42)
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, lr_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
# Out:
# Accuracy: 0.7143
# Confusion Matrix
# [[106  45]
#  [ 21  59]]
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.70      0.76       151
#           1       0.57      0.74      0.64        80
#
# avg / total       0.74      0.71      0.72       231

# %% [markdown]
# ### Training - Test Split
# * Are we being influenced by results with test data?
# * How can we evaluete training without using Testing Data?

# %% [markdown]
# ### Training - Validation - Test Split
# * We use the validation set to tune and validate our model
# * Only use the testing data for a final test
#
# #### Issues
# * How do we choose the validation data?
# * What if we don't have enough data?
# * Does this approach mitigate overtraining?

# %% [markdown]
# ### K-fold Cross Validation
# * The testing data is not used for evaluation
# * Training Data is split k-folds, each of the same size
# * One fold is selected to be the validation set
# * The rest of the folds are the training set
# * Algorithm is trained on the training set and evaluated with the fold
#   that is the validation set
# * This traing and evaluation is repeated with each fold of the training data
#     * for each fold
#         * Determine best hyperparameter value
#     * Next
#
#     * Set model hyperparameter value to average best
#
# * Is there a model that does all this work for us?
#     * YES

# %% [markdown]
# ### Algorithm CV Variants
# * scikit-learn provides special ensamble versions of the algorithms that
#       * Contain the code to determine the optimal hyperparameter value
#       * Set the model to that value
#
# * Algorithm + Cross Validation = AlgorithmCV
#
# * Name ends in "CV"
#
# * Exposes fit(), predict(), ...
#
# * Runs the algorithm K times
#
# * Can be used like normal algorithm

# %% [markdown]
# ### LogisticRegressionCV

# %%
from sklearn.linear_model import LogisticRegressionCV
lr_cv_model = LogisticRegressionCV(n_jobs=-1, random_state=42, Cs=3, cv=10, refit=False, class_weight="balanced")
lr_cv_model.fit(X_train, y_train.ravel())
# Out:
# LogisticRegressionCV(Cs=3, class_weight='balanced', cv=10, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=-1, penalty='l2', random_state=42,
#            refit=False, scoring=None, solver='lbfgs', tol=0.0001,
#            verbose=0)

# %% [markdown]
# #### Predict on Test Data

# %%
lr_cv_predict_test = lr_cv_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_cv_predict_test)))
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, lr_cv_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, lr_cv_predict_test))
# Out:
# Accuracy: 0.7056
# Confusion Matrix
# [[109  42]
#  [ 26  54]]
#
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.81      0.72      0.76       151
#           1       0.56      0.68      0.61        80
#
# avg / total       0.72      0.71      0.71       231

# %% [markdown]
# We do slightly worse than our logistic regression algorithm without cross validation *on the training set*, but are more robust for more diverse real world data.
#
# The model parameters can possibly be further modified to achive better score.

# %% [markdown]
# ## The journey from Here
#
#
# ### Pluralsight courses
# * Understanding Machine Learning with R
#
# ### Online Resources
# * UCI Machine Learning Repository
#     * archive.ics.uci.edu/ml
#
# * Jupyter Notebook
#     * https://jupyter.org/
#
# ![image.png](attachment:image.png)
